# %%
# NL to SQL - Starter Notebook

## Step 1: Install Required Libraries
# !pip install transformers
# !pip install pandas

## Step 2: Import Libraries
from transformers import pipeline
import pandas as pd

# %%
# !pip install transformers

# %%
from transformers import AutoModelWithLMHead, AutoTokenizer

# %%
model_name = "mrm8488/t5-base-finetuned-wikiSQL"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelWithLMHead.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# ...

# %%
model_name = "mrm8488/t5-base-finetuned-wikiSQL"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelWithLMHead.from_pretrained(model_name)
# Out:
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.

# %%
def nl_to_sql(query):
    input_text = f"translate English to SQL: {query} </s>"
    inputs = tokenizer(input_text, return_tensors="pt")
    outputs = model.generate(input_ids=inputs['input_ids'], attention_mask=inputs['attention_mask'])
    sql = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return sql

# %%
question = "How many models were finetuned using BERT as base model?"
generated_sql = nl_to_sql(question)
print("Generated SQL:", generated_sql)
# Out:
# Generated SQL: SELECT COUNT Model fine tuned FROM table WHERE Base model = BERT

# %%
# Example: Install python-dotenv (if not already installed)
# %pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sqlite3
import os
import google
from dotenv import load_dotenv

load_dotenv()

# Option 1: In-Memory Database (for testing)
# conn = sqlite3.connect(':memory:')

# Option 2: Temporary File (deleted when session ends)
# DATABASE_PATH = 'database.db'
# conn = sqlite3.connect(DATABASE_PATH)

# Option 3: Google Drive (persistent)
from google.colab import drive
drive.mount('/content/drive')
DATABASE_PATH = '/content/drive/MyDrive/database/database.db' # Create the folder in your drive
conn = sqlite3.connect(DATABASE_PATH)

cursor = conn.cursor()

cursor.execute('''
    CREATE TABLE IF NOT EXISTS Customers (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        name TEXT,
        city TEXT,
        country TEXT
    )
''')

# Sample data
customers = [
    ('Alice', 'New York', 'USA'),
    ('Bob', 'London', 'UK'),
    ('Charlie', 'Paris', 'France'),
    ('David', 'Tokyo', 'Japan'),
    ('Eve', 'Sydney', 'Australia')
]

cursor.executemany('INSERT INTO Customers (name, city, country) VALUES (?, ?, ?)', customers)

conn.commit()
conn.close()

# Create the .env file
with open('.env', 'w') as f:
    f.write(f'DATABASE_PATH={C:\Users\91770\NLtoSQL-AI\.env}')

# %%
# Example: Install python-dotenv (if not already installed)
# %pip install python-dotenv
